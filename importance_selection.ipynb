# %%
import numpy
import pandas as pd
import matplotlib.pyplot 
import seaborn as sns

# %%
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %%
df = pd.read_csv('매출감소사업자.csv', encoding='cp949')

# %%
df
# Out:
#       Unnamed: 0  Unnamed: 0.1       사업자번호     Cluster 산업분류코드    기업코드  \
# 0             19            19  1068186800   Cluster 1     59  9194.0
# 1           3368          3368  1178155476   Cluster 6     59     NaN
# 2           3373          3373  1138190525   Cluster 6     59     NaN
# 3            231           231  1298677497  Cluster 11     59  6859.0
# 4            723           723  5798700152  Cluster 19     59     NaN
# ...          ...           ...         ...         ...    ...     ...
# 1885        3830          3830  2208766290  Cluster 64    NaN  6156.0
# 1886        3833          3833  6338700062  Cluster 64    NaN     NaN
# 1887        3848          3848  2208790505  Cluster 64    NaN  6214.0
# 1888        3866          3866  1198175838  Cluster 64    NaN     NaN
# 1889        3870          3870  4368100168  Cluster 64    NaN     NaN
#
#       최종연구개발점수 최종연구개발등급  연구개발투자점수 인적자원구성원 등급  ...  사업계획 점수 사업계획 등급  경제적 책임 점수  \
# ...

# %%
#매출 감소 산업 비중
sns.countplot(x = df['산업분류코드'])
# Out:
# <AxesSubplot:xlabel='산업분류코드', ylabel='count'>

# %%
df1 = pd.read_csv('매출정체사업자_산업군.csv', encoding='cp949')
df1
# Out:
#         Cluster 산업분류코드
# 0     Cluster 3      P
# 1    Cluster 60      P
# 2    Cluster 32      N
# 3    Cluster 36      N
# 4    Cluster 36      N
# ..          ...    ...
# 393  Cluster 60    NaN
# 394  Cluster 60    NaN
# 395  Cluster 60    NaN
# 396  Cluster 60    NaN
# 397  Cluster 60    NaN
#
# [398 rows x 2 columns]

# %%
# 매출 정체 산업 비중
sns.countplot(x = df1['산업분류코드'])
# Out:
# <AxesSubplot:xlabel='산업분류코드', ylabel='count'>

# %%
df2 = pd.read_csv('매출증가사업자.csv', encoding='cp949')
df2
# Out:
#      Unnamed: 0  Unnamed: 0.1       사업자번호     Cluster 산업분류코드  기업코드  최종연구개발점수  \
# 0          1610          1610  2080153582   Cluster 3      C   NaN       NaN
# 1          3556          3556  2108170121  Cluster 60      C   NaN       NaN
# 2          1568          1568  1302668499   Cluster 3      C   NaN       NaN
# 3          1604          1604  1140123309   Cluster 3      C   NaN       NaN
# 4          1785          1785  1288716591  Cluster 32      C   NaN       NaN
# ..          ...           ...         ...         ...    ...   ...       ...
# 393        3566          3566  2048196790  Cluster 60    NaN   NaN       NaN
# 394        3568          3568  1448127123  Cluster 60    NaN   NaN       NaN
# 395        3578          3578  3108110608  Cluster 60    NaN   NaN       NaN
# 396        3585          3585  1138163090  Cluster 60    NaN   NaN       NaN
# 397        3589          3589  1058759919  Cluster 60    NaN   NaN       NaN
#
# ...

# %%
# 매출 상승 산업 비중
sns.countplot(x = df2['산업분류코드'])
# Out:
# <AxesSubplot:xlabel='산업분류코드', ylabel='count'>

# %%
# 결과가 거의 동일하게 나와서 업종 비율로 나누기 어려울 것으로 예상됨
