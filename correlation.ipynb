# %%
import pandas as pd
import numpy

# %%
df = pd.read_csv("사업자번호기준 병합(4).csv", encoding='euc-kr')

# %%
df.head()
# Out:
#    최종연구개발점수  연구개발집약도 점수  연구개발 연구소 점수  연구개발과제 점수  연구개발특허 점수  연구개발 제품시장성 점수  \
# 0      79.0         100           60         70         90             60
# 1      60.0          60           60         60         60             60
# 2      64.5          60           60         60         90             60
# 3      64.5          60           60         60         90             60
# 4      60.0          60           60         60         60             60
#
#    최종 마케팅 점수  고객만족도점수    광고캠페인점수  시장제공물 긍정 의견 점수  ...  대중 평판 점수  고용 평판 점수  \
# 0  46.926011     10.0  17.766011            50.0  ...        60        42
# 1  46.926011     10.0  17.766011            50.0  ...        55        54
# 2  46.926011     10.0  17.766011            50.0  ...        55        54
# 3  56.270616     10.0  27.110616            50.0  ...        50        50
# 4  46.926011     10.0  17.766011            50.0  ...        50        80
#
# ...

# %%
corr_df = df.corr

# %%
corr_df
# Out:
# <bound method DataFrame.corr of       최종연구개발점수  연구개발집약도 점수  연구개발 연구소 점수  연구개발과제 점수  연구개발특허 점수  연구개발 제품시장성 점수  \
# 0         79.0         100           60         70         90             60
# 1         60.0          60           60         60         60             60
# 2         64.5          60           60         60         90             60
# 3         64.5          60           60         60         90             60
# 4         60.0          60           60         60         60             60
# ...        ...         ...          ...        ...        ...            ...
# 5131      60.0          60           60         60         60             60
# 5132      60.0          60           60         60         60             60
# 5133      60.0          60           60         60         60             60
# 5134      78.5         100           80         80         90             60
# 5135      60.0          60           60         60         60             60
#
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

corr_df = df.corr(method='pearson')

plt.figure(figsize=(20, 20))
sns.heatmap(corr_df, annot=True)
plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 52572 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\user\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51333 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\user\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50672 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\user\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44396 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\user\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...
